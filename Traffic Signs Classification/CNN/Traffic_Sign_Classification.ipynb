# %% [markdown]
# <a href="https://colab.research.google.com/github/ItsCosmas/Traffic-Sign-Classification/blob/master/Traffic_Sign_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Clone* the *repository* containing the dataset into colab. This will allow access to the dataset inside this colab environment.

# %%
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# fatal: destination path 'german-traffic-signs' already exists and is not an empty directory.

# %%
# !ls german-traffic-signs
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# The dataset is listed above: A *spreadsheet signnames.csv* and then *pickle files containing the train, test and validate* datasets.

# %% [markdown]
# Importing the Relevant Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical
from keras.layers import Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
import pickle
import pandas as pd
import random
import cv2

# %%
np.random.seed(0)

# %% [markdown]
# *Unpickle* the Data to make it usable.

# %%
with open('german-traffic-signs/train.p', 'rb') as f:
  train_data = pickle.load(f)
with open('german-traffic-signs/valid.p', 'rb') as f:
  val_data = pickle.load(f)
with open('german-traffic-signs/test.p', 'rb') as f:
  test_data = pickle.load(f)


X_train , y_train = train_data['features'], train_data['labels']
X_val , y_val = val_data['features'], val_data['labels']
X_test , y_test = test_data['features'], test_data['labels']

# %% [markdown]
# We analyze the dataset to see how it looks like.

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %% [markdown]
# *shape* gives us the number of *images*, *dimensions in pixels* and* depth*.
# The Images have a depth of 3 because they're in **RGB** format and thus the depth 3 for each color channel.

# %% [markdown]
# Next We Assert The dataset to see if its correct

# %%
assert(X_train.shape[0] == y_train.shape[0]), "No. of Images is not equals to number of labels"
assert(X_val.shape[0] == y_val.shape[0]), "No. of Images is not equals to number of labels"
assert(X_test.shape[0] == y_test.shape[0]), "No. of Images is not equals to number of labels"

assert(X_train.shape[1:] == (32,32,3)), "The Dimesnsions of the images are not 32 x 32 x 3"
assert(X_val.shape[1:] == (32,32,3)), "The Dimesnsions of the images are not 32 x 32 x 3"
assert(X_test.shape[1:] == (32,32,3)), "The Dimesnsions of the images are not 32 x 32 x 3"

# %% [markdown]
# Showing the training set.
# If the code seems cryptic you can check out the [pandas iterrows](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iterrows.html) documentation to see how it's used to allow you to iterate over DataFrame rows as (index, Series) pairs.

# %%
data = pd.read_csv('german-traffic-signs/signnames.csv')
#print(data)

num_of_samples=[]

cols = 5
num_classes = 43

fig, axs = plt.subplots(nrows=num_classes, ncols=cols, figsize=(5,50))
fig.tight_layout()

for i in range(cols):
    for j, row in data.iterrows():
        x_selected = X_train[y_train == j]
        axs[j][i].imshow(x_selected[random.randint(0,(len(x_selected) - 1)), :, :], cmap=plt.get_cmap('gray'))
        axs[j][i].axis("off")
        if i == 2:
          axs[j][i].set_title(str(j) + " - " + row["SignName"])
          num_of_samples.append(len(x_selected))

# %% [markdown]
# Distribution of the dataset.

# %%
print(num_of_samples)
plt.figure(figsize=(12, 4))
plt.bar(range(0, num_classes), num_of_samples)
plt.title("Distribution of the train dataset")
plt.xlabel("Class number")
plt.ylabel("Number of images")
plt.show()
# Out:
# [180, 1980, 2010, 1260, 1770, 1650, 360, 1290, 1260, 1320, 1800, 1170, 1890, 1920, 690, 540, 360, 990, 1080, 180, 300, 270, 330, 450, 240, 1350, 540, 210, 480, 240, 390, 690, 210, 599, 360, 1080, 330, 180, 1860, 270, 300, 210, 210]

# %%
plt.imshow(X_train[3000])
plt.axis("off")
print(X_train[3000].shape)
print(y_train[3000])
# Out:
# (32, 32, 3)
# 1

# %% [markdown]
# Convert the image to grayscale

# %%
def grayscale(img):
  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  return img

img = grayscale(X_train[3000])
plt.imshow(img)
#plt.axis("off")
print(img.shape)
# Out:
# (32, 32)

# %% [markdown]
# Next We apply the Histogram Equalization technique to standardize lighting in all our images. [Histogram Equalization Here](https://en.wikipedia.org/wiki/Histogram_equalization)

# %%
def equalize(img):
  img = cv2.equalizeHist(img)
  return img


img = equalize(img)
plt.imshow(img)
print(img.shape)
# Out:
# (32, 32)

# %% [markdown]
# Next We apply Preprocessing to all our images.

# %%
def preprocessing(img):
  img = grayscale(img)
  img = equalize(img)
  #normalize the images, convert the pixel values to fit btwn 0 and 1
  img = img/255
  return img

# %% [markdown]
# Map Function Iterates through an entire array and perfoms a given operation. You can read about it  [here](https://www.journaldev.com/22960/python-map-function).

# %%
X_train = np.array(list(map(preprocessing, X_train)))
X_val = np.array(list(map(preprocessing, X_val)))
X_test = np.array(list(map(preprocessing, X_test)))

# %% [markdown]
# Random image from our train data to see that its correctly preprocessed

# %%
plt.imshow(X_train[random.randint(0, len(X_train) - 1)])
print(X_train.shape)
# Out:
# (34799, 32, 32)

# %% [markdown]
# Next We add a depth to our images, that is required for our Convolutional Layer

# %%
X_train = X_train.reshape(34799, 32, 32, 1)
X_val = X_val.reshape(4410, 32, 32, 1)
X_test = X_test.reshape(12630, 32, 32, 1)

# %% [markdown]
# We generate variety datasets to better the model

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(width_shift_range=0.1,
                             height_shift_range=0.1,
                            zoom_range=0.2,
                            shear_range=0.1,
                            rotation_range=10.)

datagen.fit(X_train)

# %%
batches = datagen.flow(X_train, y_train, batch_size = 15)
X_batch, y_batch = next(batches)

fig, axs = plt.subplots(1, 15, figsize=(20, 5))
fig.tight_layout()

for i in range(15):
    axs[i].imshow(X_batch[i].reshape(32, 32))
    axs[i].axis("off")

print(X_batch.shape)
# Out:
# (15, 32, 32, 1)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 1)
# (4410, 32, 32, 1)
# (12630, 32, 32, 1)

# %% [markdown]
# Next One Hot Encode the data labels. Here's an article [one-hot encoding](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f).

# %%
y_train = to_categorical(y_train, 43)
y_val = to_categorical(y_val, 43)
y_test = to_categorical(y_test, 43)

# %% [markdown]
# Next, It's time to define a model.[here](https://medium.com/@mgazar/lenet-5-in-9-lines-of-code-using-keras-ac99294c8086)

# %%
def better_model():
  model = Sequential()
  # add the convolutional layer
  #filters, size of filters,input_shape,activation_function
  model.add(Conv2D(60,(5,5), input_shape= (32,32,1), activation = 'relu'))
  model.add(Conv2D(60,(5,5), input_shape= (32,32,1), activation = 'relu'))
  #pooling layer
  model.add(MaxPooling2D(pool_size = (2,2)))
  # add another convolutional layer
  model.add(Conv2D(30, (3, 3) , activation = 'relu'))
  model.add(Conv2D(30, (3, 3) , activation = 'relu'))
  # pooling layer
  model.add(MaxPooling2D(pool_size = (2,2)))
  
  #model.add(Dropout(0.5))
  
  #Flatten the image to 1 dimensional array
  model.add(Flatten())
  #add a dense layer : amount of nodes, activation
  model.add(Dense(500, activation = 'relu'))
  # place a dropout layer
  #0.5 drop out rate is recommended, half input nodes will be dropped at each update
  model.add(Dropout(0.5))
  # defining the ouput layer of our network
  model.add(Dense(num_classes, activation = 'softmax'))
  
  
  #Compile Model
  
  model.compile(Adam(lr = 0.001), loss = 'categorical_crossentropy', metrics = ['accuracy'])
  
  return model

# %%
model = better_model()
#print a summary of the model
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 60)        1560
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 60)        90060
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 60)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 30)        16230
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 30)          8130
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 30)         0
#  2D)
#
#  flatten (Flatten)           (None, 480)               0
#
#  dense (Dense)               (None, 500)               240500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_1 (Dense)             (None, 43)                21543
#
# =================================================================
# Total params: 378,023
# Trainable params: 378,023
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\codi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# Now to training and evaluating the model

# %%
# define our training paramters
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=50),
                            steps_per_epoch=696,
                            epochs=15,
                            validation_data=(X_val, y_val), shuffle = 1)
# Out:
# C:\Users\codi\AppData\Local\Temp\ipykernel_15952\3378759563.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=50),
# Epoch 1/15
# 696/696 [==============================] - 75s 106ms/step - loss: 1.7651 - accuracy: 0.5042 - val_loss: 0.3147 - val_accuracy: 0.9109
# Epoch 2/15
# 696/696 [==============================] - 73s 105ms/step - loss: 0.5512 - accuracy: 0.8322 - val_loss: 0.1511 - val_accuracy: 0.9508
# Epoch 3/15
# 696/696 [==============================] - 73s 105ms/step - loss: 0.3392 - accuracy: 0.8942 - val_loss: 0.1497 - val_accuracy: 0.9528
# Epoch 4/15
# 696/696 [==============================] - 72s 104ms/step - loss: 0.2626 - accuracy: 0.9170 - val_loss: 0.0670 - val_accuracy: 0.9825
# Epoch 5/15
# 696/696 [==============================] - 73s 105ms/step - loss: 0.2127 - accuracy: 0.9348 - val_loss: 0.0724 - val_accuracy: 0.9794
# Epoch 6/15
# 696/696 [==============================] - 74s 106ms/step - loss: 0.1903 - accuracy: 0.9407 - val_loss: 0.0673 - val_accuracy: 0.9762
# Epoch 7/15
# 696/696 [==============================] - 75s 108ms/step - loss: 0.1642 - accuracy: 0.9494 - val_loss: 0.0717 - val_accuracy: 0.9791
# Epoch 8/15
# 696/696 [==============================] - 73s 105ms/step - loss: 0.1575 - accuracy: 0.9520 - val_loss: 0.0582 - val_accuracy: 0.9825
# Epoch 9/15
# 696/696 [==============================] - 74s 106ms/step - loss: 0.1349 - accuracy: 0.9579 - val_loss: 0.0895 - val_accuracy: 0.9812
# Epoch 10/15
# 696/696 [==============================] - 72s 103ms/step - loss: 0.1299 - accuracy: 0.9597 - val_loss: 0.0499 - val_accuracy: 0.9839
# Epoch 11/15
# 696/696 [==============================] - 73s 105ms/step - loss: 0.1223 - accuracy: 0.9613 - val_loss: 0.0455 - val_accuracy: 0.9864
# Epoch 12/15
# 696/696 [==============================] - 71s 102ms/step - loss: 0.1074 - accuracy: 0.9667 - val_loss: 0.0483 - val_accuracy: 0.9832
# Epoch 13/15
# 696/696 [==============================] - 74s 106ms/step - loss: 0.1064 - accuracy: 0.9669 - val_loss: 0.0565 - val_accuracy: 0.9864
# Epoch 14/15
# 696/696 [==============================] - 72s 104ms/step - loss: 0.1000 - accuracy: 0.9691 - val_loss: 0.0358 - val_accuracy: 0.9914
# Epoch 15/15
# 696/696 [==============================] - 74s 106ms/step - loss: 0.0983 - accuracy: 0.9705 - val_loss: 0.0506 - val_accuracy: 0.9837

# %% [markdown]
# How the network perfomed:

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'])
plt.title('Model Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %% [markdown]
# Evaluate the model

# %%
score = model.evaluate(X_test, y_test , verbose = 0)
print("The test score is: ",score[0])
print("The Accuracy score is: ",score[1])
# Out:
# The test score is:  0.11043312400579453
# The Accuracy score is:  0.9690419435501099

# %% [markdown]
# Time to test the image on real images from the internet

# %%
#fetch image

import requests
from PIL import Image
url = 'https://c8.alamy.com/comp/A0RX23/cars-and-automobiles-must-turn-left-ahead-sign-A0RX23.jpg'
r = requests.get(url, stream=True)
img = Image.open(r.raw)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
#Preprocess image

img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
plt.imshow(img, cmap = plt.get_cmap('gray'))
print(img.shape)
# Out:
# (32, 32)

# %%
#Reshape reshape

img = img.reshape(1, 32, 32, 1)

# %%
#Test image
print("The Predicted sign: "+ str(np.argmax(model.predict(img), axis=-1)))
# Out:
# 1/1 [==============================] - 0s 110ms/step
# The Predicted sign: [38]

# %% [markdown]
# Saving the model for later use

# %%
from keras.models import load_model

model.save('my_model_test.h5')  # creates a HDF5 file 'my_model.h5'
del model # deletes the existing model

# %%
# returns a compiled model
# identical to the previous one
model = load_model('my_model_test.h5')

# %% [markdown]
# The saved Model can be tested now

# %%
#Testing the Saved Model

#fetch image

import requests
from PIL import Image
url = 'https://previews.123rf.com/images/pejo/pejo0907/pejo090700003/5155701-german-traffic-sign-no-205-give-way.jpg'
r = requests.get(url, stream=True)
img = Image.open(r.raw)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %%
#Preprocess image

img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
plt.imshow(img, cmap = plt.get_cmap('gray'))
print(img.shape)
# Out:
# (32, 32)

# %%
#Reshape reshape

img = img.reshape(1, 32, 32, 1)

# %%
#Test image
print("The Predicted sign: "+ str(np.argmax(model.predict(img), axis=-1)))
# Out:
# 1/1 [==============================] - 0s 83ms/step
# The Predicted sign: [13]
